# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv('survey_results_public.csv')
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df["Employment"].isnull().mean() # looking for missing values
# Out:
# 0.01914876860592014

# %%
df["Country"].isnull().mean() # looking for missing values 
df.dropna() #drop missing values
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 19             20  I am not primarily a developer, but I write co...       No
# 38             39                     I am a developer by profession      Yes
# 43             44                     I am a developer by profession      Yes
# 82             83                     I am a developer by profession      Yes
# 103           104                     I am a developer by profession      Yes
# 127           128  I am not primarily a developer, but I write co...      Yes
# 230           232                     I am a developer by profession      Yes
# 239           241                     I am a developer by profession      Yes
# 284           286                     I am a developer by profession      Yes
# 309           311                     I am a developer by profession       No
# 432           434                     I am a developer by profession      Yes
# ...

# %%
#Question 1: What percentage of developers are employed ful time and part time? 
emp = df.Employment.value_counts()
(emp/df.shape[0]).plot(kind = "bar");
plt.title("Employment Status")
# Out:
# Text(0.5,1,'Employment Status')

# %%
#Answer to Question 1: About 70% of the developers are employed full time, and 5% employed part time

# %%
#Question 2: How many hours does each developer work on average?
df.describe()
# Out:
#          Respondent     CompTotal  ConvertedComp   WorkWeekHrs    CodeRevHrs  \
# count  88883.000000  5.594500e+04   5.582300e+04  64503.000000  49790.000000
# mean   44442.000000  5.519014e+11   1.271107e+05     42.127197      5.084308
# std    25658.456325  7.331926e+13   2.841523e+05     37.287610      5.513931
# min        1.000000  0.000000e+00   0.000000e+00      1.000000      0.000000
# 25%    22221.500000  2.000000e+04   2.577750e+04     40.000000      2.000000
# 50%    44442.000000  6.200000e+04   5.728700e+04     40.000000      4.000000
# 75%    66662.500000  1.200000e+05   1.000000e+05     44.750000      6.000000
# max    88883.000000  1.000000e+16   2.000000e+06   4850.000000     99.000000
#
#                 Age
# count  79210.000000
# mean      30.336699
# std        9.178390
# min        1.000000
# 25%       24.000000
# 50%       29.000000
# 75%       35.000000
# max       99.000000

# %%
#Answer to Question 2: Average work week is 42.12 hours.

#Question 3: Do developers who work more hours make more money?
sns.heatmap(df.corr(), annot=True, fmt=".2f");
